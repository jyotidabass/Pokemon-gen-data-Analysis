# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_attributes.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen5.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_alter_form_type.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen6.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen3.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_list.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_regional_forms.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen9.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_dex.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_stats.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen4.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_type.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen8.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen2.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen1.csv
# /kaggle/input/pokemon-gen-1-to-gen-9/pokemon_abilities.csv
# ...

# %% [markdown]
# # **Import library and dataset and visualize data**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_abilities.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ndex               1010 non-null   float64
#  1   name               1022 non-null   object
#  2   pokemon_abilities  1010 non-null   object
# dtypes: float64(1), object(2)
# memory usage: 24.1+ KB
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_alter_form_type.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 168 entries, 0 to 167
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ndex             168 non-null    int64
#  1   name             168 non-null    object
#  2   form             168 non-null    object
#  3   pokemon_type1    168 non-null    object
#  4   pokemon_type1.1  115 non-null    object
# dtypes: int64(1), object(4)
# memory usage: 6.7+ KB
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_attributes.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               1015 non-null   object
#  1   ndex               1010 non-null   float64
#  2   pokemon_species    1015 non-null   object
#  3   pokemon_weight_kg  1005 non-null   float64
#  4   pokemon_height_m   1003 non-null   float64
#  5   pokemon_male       862 non-null    float64
#  6   pokemon_female     863 non-null    object
# dtypes: float64(4), object(3)
# memory usage: 55.6+ KB
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_data_gen1.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 151 entries, 0 to 150
# Data columns (total 28 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              151 non-null    int64
#  1   name               151 non-null    object
#  2   type               151 non-null    object
#  3   pokemon_species    151 non-null    object
#  4   pokemon_abilities  151 non-null    object
#  5   pokemon_weight     151 non-null    object
#  6   pokemon_height     151 non-null    object
#  7   pokemon_male       138 non-null    float64
#  8   pokemon_female     138 non-null    float64
#  9   pokemon_egg        144 non-null    object
#  10  kanto_number       151 non-null    int64
#  11  joto_number        89 non-null     float64
#  12  joto_h_number      89 non-null     float64
#  13  hoenn_number       46 non-null     float64
#  14  hoenn_oa_number    46 non-null     float64
#  15  sinnoh_number      33 non-null     float64
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_type.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1015 non-null   object
#  1   ndex        1010 non-null   float64
#  2   Unnamed: 2  1015 non-null   object
#  3   Unnamed: 3  765 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 31.8+ KB
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_type.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1015 entries, 0 to 1014
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   name        1015 non-null   object
#  1   ndex        1010 non-null   float64
#  2   Unnamed: 2  1015 non-null   object
#  3   Unnamed: 3  765 non-null    object
# dtypes: float64(1), object(3)
# memory usage: 31.8+ KB
# <Axes: >

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv(r"/kaggle/input/pokemon-gen-1-to-gen-9/pokemon_regional_forms.csv")
df.describe(include="all")
df.info()
df.shape
df.head(5).T
df.isnull().sum()
sns.heatmap(df.isna())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              60 non-null     object
#  1   national_dex      60 non-null     int64
#  2   region            60 non-null     object
#  3   pokemon_type1     60 non-null     object
#  4   pokemon_type2     46 non-null     object
#  5   pokemon_ability1  60 non-null     object
#  6   pokemon_ability2  37 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 3.4+ KB
# <Axes: >
